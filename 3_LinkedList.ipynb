# %% [markdown]
# # Data Structures & Algorithms Tutorials in Python
# https://github.com/codebasics/data-structures-algorithms-python/tree/master/data_structures/3_LinkedList

# %%
#Linked Lists
class Node:
    def __init__(self, data=None, next=None, prev = None):
        self.data = data
        self.next = next
        self.prev = prev

class LinkedList:
    def __init__(self):
        self.head = None
        self.prev = None
    def insert_at_begining(self, data):
        node = Node(data, self.head, None)
        if self.head != None:
            self.head.prev = node
        else:
            self.prev = node
        self.head = node
    def print(self):
        if self.head is None:
            print("Linked List is empty")
            return
        itr = self.head
        llstr = ''
        while itr:
            llstr += str(itr.data) + '-->'
            itr = itr.next
        print(llstr)
    def insert_at_end(self, data):
        node = Node(data, None, self.prev)
        if self.prev != None:
            self.prev.next = node
        else:
            self.head = node
        self.prev = node
    def insert_values(self,data_list):
        self.head = None
        for data in data_list:
            self.insert_at_end(data)
            #print(data)
    def get_length(self):
        count = 0
        itr = self.head
        while itr:
            count+=1
            itr = itr.next
        return count
    def remove_at(self, index):
        selfLen = self.get_length()
        #print(index, selfLen)
        if index <0 or index >= selfLen:
            raise Exception("Invalid index")
        if index == 0:
            self.head = self.head.next
            self.head.prev = None
            return
        if index == selfLen-1:
            self.prev = self.prev.prev
            self.prev.next = None
            return
        count = 0
        itr = self.head
        while itr:
            if count == index:
                itr.next.prev = itr.prev
                itr.prev.next = itr.next
                return
            itr = itr.next
            count += 1
    def insert_at(self, index, data):
        selfLen = self.get_length()
        if index <0 or index >= selfLen:
            raise Exception("Invalid index")
        if index == 0:
            self.insert_at_begining(data)
            return
        if index == selfLen -1:
            self.insert_at_end(data):
            return
        count = 0
        itr = self.head
        lastIr = itr
        while itr:
            itr = itr.next
            if count == index:
                
            lastItr = itr
            count += 1
    def insert_after_value(self, data_after,data_to_insert):  
        count = 0
        itr = self.head
        lastItr = itr
        while itr:
            if itr == self.head:
                self.head = itr.next
                lastItr.next = itr.next
                break
            if itr.data == data_after:
                node = Node(data_to_insert, itr.next)
                itr.next = node
                break
            count +=1 
            itr = itr.next
            lastItr = lastItr.next
        #search for first occuance of data-after value in ll
        #insert data_to_insert after data_after node
    
    def remove_by_value(self, data):                          
        # Remove first node that contains data
        itr = self.head
        lastItr = itr
        while itr:
            if itr.data == data:
                if itr == self.head:
                    self.head = itr.next
                lastItr.next = itr.next
                break
            lastItr = itr
            itr = itr.next
    def print_forward(self):                                 
    # This method prints list in forward direction. Use node.next
        self.print()
    def print_backward(self):                                
        # Print linked list in reverse direction. Use node.prev for this.      
        pass
            
            
        
if __name__ == '__main__':
    ll = LinkedList()
    ll.insert_values(["banana","mango","grapes","orange"])
    #ll.print()
    #ll.insert_at_begining("kiwi")
    ll.remove_at(3)
    ll.print()
# Out:
# 3 4
# banana-->mango-->grapes-->
